# %% [markdown]
# # HS4002 Week 3
#
# ## Data Preparation
#
# This week we need the `scipy` library for skewness and kurtosis statistics.
#
# Make sure `gss2022_mini.csv` is in the same folder.

# %%
# !pip install pandas numpy scipy plotnine

import pandas as pd
import numpy as np
import plotnine as p9
import warnings
warnings.filterwarnings('ignore')
from scipy.stats import skew, kurtosis

# %% [markdown]
# ## Select variables of interest

# %%
raw_df = pd.read_csv("gss2022_mini.csv")

chosen_variables = [
	"id", "yrlvmus" , 'yrartxbt', 'yrmovie', 'yrcreat', 'income16', 'prestg10' ]
	
df = raw_df[chosen_variables].copy()

# %%
df["income16"].value_counts()
# Out:
# income16
# 26.0    330
# 20.0    304
# 22.0    249
# 21.0    240
# 19.0    239
# 18.0    211
# 23.0    169
# 16.0    162
# 17.0    152
# 24.0    147
# 15.0    129
# 9.0     104
# 14.0    100
# 25.0     97
# 13.0     92
# 10.0     83
# 11.0     64
# 12.0     51
# 8.0      40
# 1.0      39
# 2.0      33
# 3.0      18
# 5.0      16
# 7.0      16
# 6.0      14
# 4.0      11
# Name: count, dtype: int64

# %% [markdown]
# ## Remove all rows with missing values

# %%
df = df.dropna()

# %% [markdown]
# ## Recode categorical variables into binary variables
#
# `1 = attended / participated`, `0 = did not`. Refer to the GSS Codebook for coding.

# %%
df['binary_lvmus']  = np.where(df['yrlvmus']  == 1, 1, 0)
df['binary_artxbt'] = np.where(df['yrartxbt']  == 1, 1, 0)
df['binary_movie']  = np.where(df['yrmovie']  == 1, 1, 0)
df['binary_creat']  = np.where(df['yrcreat']  == 1, 1, 0)

# %% [markdown]
# ## Recode income into a continuous variable
#
# `income16` is an ordinal variable (income brackets). Standard practice assigns each person the midpoint of their bracket. In Python, a dictionary lookup is much cleaner than nested `ifelse()` calls.

# %%
# Recode income16 (ordinal brackets) to continuous midpoint values
# This replaces the deeply nested ifelse() chain from the R version
income_map = {
	1: 500, 2: 2000, 3: 3500, 4: 4500, 5: 5500, 6: 6500, 7: 7500, 8: 9000, 9: 11250,
	10: 13750, 11: 16250, 12: 18750, 13: 21250, 14: 23750, 15: 27500, 16: 32500, 17: 37500,
	18: 45000, 19: 55000, 20: 67500, 21: 82500, 22: 100000, 23: 120000, 24: 140000, 25: 160000,
	26: 250000
}
df['income_cont'] = df['income16'].map(income_map)
df["income_cont"].mean()
# Out:
# np.float64(87334.82142857143)

# %% [markdown]
# ## Make a new variable for the omnivorousness index
#
# Sum the four binary cultural participation variables.

# %%
df = df.assign(
	omni=(
		df['binary_lvmus']
		+ df['binary_artxbt']
		+ df['binary_movie']
		+ df['binary_creat']
	)
)
df["omni"].value_counts()
# Out:
# omni
# 2    201
# 1    183
# 0    155
# 3    124
# 4     65
# Name: count, dtype: int64

# %% [markdown]
# ## Produce 3 samples
#
# Sizes n = 30 (small), n = 100 (medium), and n = 500 (large).

# %%
np.random.seed(47)
df_small  = df.sample(n=30,  random_state=47)
df_medium = df.sample(n=100, random_state=47)
df_large  = df.sample(n = 500, random_state = 47)

# %% [markdown]
# # Compare Distributions of Categorical Variables Across Samples
#
# ## What proportion attended live music last year?

# %%
print("Small:")
print(df_small['binary_lvmus'].value_counts(normalize=True))
print("medium:")
print(df_medium['binary_lvmus'].value_counts(normalize=True))
print("Large:")
print(df_large['binary_lvmus'].value_counts(normalize=True))
print("Full GSS:")
print(df['binary_lvmus'].value_counts(normalize=True))
# Out:
# Small:
# binary_lvmus
# 1    0.6
# 0    0.4
# Name: proportion, dtype: float64
# medium:
# binary_lvmus
# 1    0.6
# 0    0.4
# Name: proportion, dtype: float64
# Large:
# binary_lvmus
# 1    0.524
# 0    0.476
# Name: proportion, dtype: float64
# Full GSS:
# binary_lvmus
# 1    0.523352
# 0    0.476648
# Name: proportion, dtype: float64

# %% [markdown]
# ## What proportion visited an art exhibit last year?

# %%
print("Small:")
print(df_small['binary_artxbt'].value_counts(normalize=True))
print("medium:")
print(df_medium['binary_artxbt'].value_counts(normalize=True))
print("Large:")
print(df_large['binary_artxbt'].value_counts(normalize=True))
print("Full GSS:")
print(df['binary_artxbt'].value_counts(normalize=True))
# Out:
# Small:
# binary_artxbt
# 0    0.8
# 1    0.2
# Name: proportion, dtype: float64
# medium:
# binary_artxbt
# 0    0.67
# 1    0.33
# Name: proportion, dtype: float64
# Large:
# binary_artxbt
# 0    0.636
# 1    0.364
# Name: proportion, dtype: float64
# Full GSS:
# binary_artxbt
# 0    0.656593
# 1    0.343407
# Name: proportion, dtype: float64

# %% [markdown]
# ## Plot a bar chart for movie-watching (large sample)

# %%
p = (
	p9.ggplot(df_large) +
	p9.geom_bar(p9.aes(x='factor(binary_lvmus)'), width=0.3) +
	p9.theme_light() +
	p9.labs(x='Live Music (1 = Yes)', y='Count',
			title='Distribution of Live Music Over Past Year',
			subtitle='Data from GSS 2022')
)
p.save('bar_music.png', width=12, height=8.5, units='cm')
p

# %% [markdown]
# ## Plot a histogram of the omnivorousness index

# %%
p = (
	p9.ggplot(df_small) +
	p9.geom_histogram(p9.aes(x='income_cont'), binwidth=1) +
	p9.theme_light() +
	p9.labs(x='Income', y='Count',
			title='Distribution of Income',
			subtitle='Data from GSS 2022')
)
p.save('hist_income.png', width=15, height=10.5, units='cm')
p
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/hs4002_ay26/.venv/lib/python3.14/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:2761, in pandas._libs.hashtable.Int64HashTable.get_item()
# -> 2761 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:2785, in pandas._libs.hashtable.Int64HashTable.get_item()
# -> 2785 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 142608
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 9
#       5 	p9.labs(x='Income', y='Count',
#       6                         title='Distribution of Income',
#       7                         subtitle='Data from GSS 2022')
#       8 )
# ----> 9 p.save('hist_income.png', width=15, height=10.5, units='cm')
#      10 p
#
# File ~/Documents/hs4002_ay26/.venv/lib/python3.14/site-packages/plotnine/ggplot.py:681, in ggplot.save(self, filename, format, path, width, height, units, dpi, limitsize, verbose, **kwargs)
#     632 def save(
#     633     self,
#     634     filename: Optional[str | Path | BytesIO] = None,
#    (...)    643     **kwargs: Any,
#     644 ):
#     645     """
#     646     Save a ggplot object as an image file
#     647
#    (...)    679         Additional arguments to pass to matplotlib `savefig()`.
#     680     """
# --> 681     sv = self.save_helper(
#     682         filename=filename,
#     683         format=format,
#     684         path=path,
#     685         width=width,
#     686         height=height,
#     687         units=units,
#     688         dpi=dpi,
#     689         limitsize=limitsize,
#     690         verbose=verbose,
#     691         **kwargs,
#     692     )
#     694     with plot_context(self).rc_context:
#     695         sv.figure.savefig(**sv.kwargs)
#
# File ~/Documents/hs4002_ay26/.venv/lib/python3.14/site-packages/plotnine/ggplot.py:629, in ggplot.save_helper(self, filename, format, path, width, height, units, dpi, limitsize, verbose, **kwargs)
#     626 if dpi is not None:
#     627     self.theme = self.theme + theme(dpi=dpi)
# --> 629 figure = self.draw(show=False)
#     630 return mpl_save_view(figure, fig_kwargs)
#
# File ~/Documents/hs4002_ay26/.venv/lib/python3.14/site-packages/plotnine/ggplot.py:306, in ggplot.draw(self, show)
#     304 with plot_context(self, show=show):
#     305     figure = self._setup()
# --> 306     self._build()
#     308     # setup
#     309     self.axs = self.facet.setup(self)
#
# File ~/Documents/hs4002_ay26/.venv/lib/python3.14/site-packages/plotnine/ggplot.py:393, in ggplot._build(self)
#     390 layout.map_position(layers)
#     392 # Apply and map statistics
# --> 393 layers.compute_statistic(layout)
#     394 layers.map_statistic(self)
#     396 # Prepare data in geoms
#     397 # e.g. from y and width to ymin and ymax
#
# File ~/Documents/hs4002_ay26/.venv/lib/python3.14/site-packages/plotnine/layer.py:489, in Layers.compute_statistic(self, layout)
#     487 def compute_statistic(self, layout: Layout):
#     488     for l in self:
# --> 489         l.compute_statistic(layout)
#
# File ~/Documents/hs4002_ay26/.venv/lib/python3.14/site-packages/plotnine/layer.py:293, in layer.compute_statistic(self, layout)
#     291 data = self.stat.use_defaults(data)
#     292 data = self.stat.setup_data(data)
# --> 293 data = self.stat.compute_layer(data, layout)
#     294 self.data = data
#
# File ~/Documents/hs4002_ay26/.venv/lib/python3.14/site-packages/plotnine/stats/stat.py:303, in stat.compute_layer(self, data, layout)
#     300     pscales = layout.get_scales(pdata["PANEL"].iloc[0])
#     301     return self.compute_panel(pdata, pscales)
# --> 303 return groupby_apply(data, "PANEL", fn)
#
# File ~/Documents/hs4002_ay26/.venv/lib/python3.14/site-packages/plotnine/_utils/__init__.py:571, in groupby_apply(df, cols, func, *args, **kwargs)
#     567 lst = []
#     568 for _, d in df.groupby(cols, observed=True):
#     569     # function fn should be free to modify dataframe d, therefore
#     570     # do not mark d as a slice of df i.e no SettingWithCopyWarning
# --> 571     lst.append(func(d, *args, **kwargs))
#     572 return pd.concat(lst, axis=axis, ignore_index=True)
#
# File ~/Documents/hs4002_ay26/.venv/lib/python3.14/site-packages/plotnine/stats/stat.py:301, in stat.compute_layer.<locals>.fn(pdata)
#     299     return pdata
#     300 pscales = layout.get_scales(pdata["PANEL"].iloc[0])
# --> 301 return self.compute_panel(pdata, pscales)
#
# File ~/Documents/hs4002_ay26/.venv/lib/python3.14/site-packages/plotnine/stats/stat.py:335, in stat.compute_panel(self, data, scales)
#     333 stats = []
#     334 for _, old in data.groupby("group"):
# --> 335     new = self.compute_group(old, scales)
#     336     new.reset_index(drop=True, inplace=True)
#     337     unique = uniquecols(old)
#
# File ~/Documents/hs4002_ay26/.venv/lib/python3.14/site-packages/plotnine/stats/stat_bin.py:135, in stat_bin.compute_group(self, data, scales)
#     127 else:
#     128     breaks = breaks_from_bins(
#     129         scales.x.dimension(),
#     130         params["bins"],
#     131         params["center"],
#     132         params["boundary"],
#     133     )
# --> 135 new_data = assign_bins(
#     136     data["x"],
#     137     breaks,
#     138     data.get("weight"),
#     139     params["pad"],
#     140     params["closed"],
#     141 )
#     142 return new_data
#
# File ~/Documents/hs4002_ay26/.venv/lib/python3.14/site-packages/plotnine/stats/binning.py:199, in assign_bins(x, breaks, weight, pad, closed)
#     197     empty_bins = set(range(len(bin_x))) - set(bin_idx)
#     198     for b in empty_bins:
# --> 199         wftable.loc[b] = 0  # pyright: ignore
#     200     wftable = wftable.sort_index()
#     201 bin_count = wftable.tolist()
#
# File ~/Documents/hs4002_ay26/.venv/lib/python3.14/site-packages/pandas/core/indexing.py:932, in _LocationIndexer.__setitem__(self, key, value)
#     930     maybe_callable = com.apply_if_callable(key, self.obj)
#     931     key = self._raise_callable_usage(key, maybe_callable)
# --> 932 indexer = self._get_setitem_indexer(key)
#     933 self._has_valid_setitem_indexer(key)
#     935 iloc: _iLocIndexer = (
#     936     cast("_iLocIndexer", self) if self.name == "iloc" else self.obj.iloc
#     937 )
#
# File ~/Documents/hs4002_ay26/.venv/lib/python3.14/site-packages/pandas/core/indexing.py:807, in _LocationIndexer._get_setitem_indexer(self, key)
#     803 if isinstance(key, range):
#     804     # GH#45479 test_loc_setitem_range_key
#     805     key = list(key)
# --> 807 return self._convert_to_indexer(key, axis=0)
#
# File ~/Documents/hs4002_ay26/.venv/lib/python3.14/site-packages/pandas/core/indexing.py:1511, in _LocIndexer._convert_to_indexer(self, key, axis)
#    1504 if is_scalar(key) or (
#    1505     isinstance(labels, MultiIndex) and is_hashable(key) and not contains_slice
#    1506 ):
#    1507     # Otherwise get_loc will raise InvalidIndexError
#    1508
#    1509     # if we are a label return me
#    1510     try:
# -> 1511         return labels.get_loc(key)
#    1512     except LookupError:
#    1513         if isinstance(key, tuple) and isinstance(labels, MultiIndex):
#
# File ~/Documents/hs4002_ay26/.venv/lib/python3.14/site-packages/pandas/core/indexes/base.py:3644, in Index.get_loc(self, key)
#    3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#    3643     if isinstance(casted_key, slice) or (
# -> 3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
#    3648     raise KeyError(key) from err
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/abc.py:117, in ABCMeta.__instancecheck__(cls, instance)
#     111     """Register a virtual subclass of an ABC.
#     112
#     113     Returns the subclass, to allow usage as a class decorator.
#     114     """
#     115     return _abc_register(cls, subclass)
# --> 117 def __instancecheck__(cls, instance):
#     118     """Override for isinstance(instance, cls)."""
#     119     return _abc_instancecheck(cls, instance)
#
# KeyboardInterrupt:

# %% [markdown]
# # Compare Distributions of Two Continuous Variables
#
# We compare household income with occupational prestige using the large sample.
#
# ## Scale the variables
#
# Standardize so both variables are on the same scale (mean = 0, SD = 1). Equivalent to R's `scale()`.

# %%
df_large = df_large.copy()
df_large['scaled_income'] = (df_large['income_cont'] - df_large['income_cont'].mean()) / df_large['income_cont'].std()
df_large['scaled_prestg'] = (df_large['prestg10'] - df_large['prestg10'].mean()) / df_large['prestg10'].std()

# %% [markdown]
# ## Plot the distributions of each variable

# %%
p = (
	p9.ggplot(df_large) +
	p9.geom_histogram(p9.aes(x='scaled_income'), bins=50, fill='purple') +
	p9.theme_light() +
	p9.labs(x='Normalized Values', y='Count',
			title='Distribution of Household Income', subtitle='Data from GSS 2022')
)
p.save('hist_income.png', width=15, height=10.5, units='cm')
p

# %%
p = (
	p9.ggplot(df_large) +
	p9.geom_histogram(p9.aes(x='scaled_prestg'), bins=50, fill='darkorange') +
	p9.theme_light() +
	p9.labs(x='Normalized Values', y='Count',
			title='Distribution of Job Prestige', subtitle='Data from GSS 2022')
)
p.save('hist_prestg.png', width=15, height=10.5, units='cm')
p

# %% [markdown]
# ## Calculate Skewness of each variable
#
# Skewness > 0 is right-skewed (long right tail); < 0 is left-skewed.

# %%
print('Skewness of Income (scaled):',  skew(df_large['scaled_income']))
# Out:
# Skewness of Income (scaled): 1.1554791279182701

# %% [markdown]
# ## Calculate Kurtosis of each variable
#
# `scipy.stats.kurtosis` with `fisher=False` gives Pearson kurtosis (same as R's `moments::kurtosis`). A normal distribution has kurtosis ≈ 3 (mesokurtic); > 3 is leptokurtic.

# %%
# fisher=False gives Pearson kurtosis — equivalent to R's moments::kurtosis()
print('Kurtosis of Income (scaled):',  kurtosis(df_large['scaled_income'], fisher=False))
# Out:
# Kurtosis of Income (scaled): 3.4243314036352643
